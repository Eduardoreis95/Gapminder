# %% [markdown]
# ## Importação das Bibliotecas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ## Base de Dados

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/CSV and Excel/Gapminder.csv", error_bad_lines=False, sep=";")

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 3307     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 3308     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 3309     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 3310     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 3311     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [3312 rows x 6 columns]

# %%
df = df.rename(columns={"country": "Pais", "continent": "Continente", "year": "Ano", "lifeExp": "Expectativa de Vida", "pop": "Pop Total", "gdpPercap": "PIB"})

# %%
df
# Out:
#              Pais Continente   Ano  Expectativa de Vida  Pop Total         PIB
# 0     Afghanistan       Asia  1952               28.801    8425333  779.445314
# 1     Afghanistan       Asia  1957               30.332    9240934  820.853030
# 2     Afghanistan       Asia  1962               31.997   10267083  853.100710
# 3     Afghanistan       Asia  1967               34.020   11537966  836.197138
# 4     Afghanistan       Asia  1972               36.088   13079460  739.981106
# ...           ...        ...   ...                  ...        ...         ...
# 3307     Zimbabwe     Africa  1987               62.351    9216418  706.157306
# 3308     Zimbabwe     Africa  1992               60.377   10704340  693.420786
# 3309     Zimbabwe     Africa  1997               46.809   11404948  792.449960
# 3310     Zimbabwe     Africa  2002               39.989   11926563  672.038623
# 3311     Zimbabwe     Africa  2007               43.487   12311143  469.709298
#
# [3312 rows x 6 columns]

# %%
df.shape
# Out:
# (3312, 6)

# %%
df.columns
# Out:
# Index(['Pais', 'Continente', 'Ano', 'Expectativa de Vida', 'Pop Total', 'PIB'], dtype='object')

# %%
df.dtypes
# Out:
# Pais                    object
# Continente              object
# Ano                      int64
# Expectativa de Vida    float64
# Pop Total                int64
# PIB                    float64
# dtype: object

# %%
df.describe()
# Out:
#                Ano  Expectativa de Vida     Pop Total            PIB
# count  3312.000000          3312.000000  3.312000e+03    3312.000000
# mean   1980.301630            65.246871  3.161489e+07   11317.115805
# std      16.927294            11.768412  1.041193e+08   11369.142739
# min    1950.000000            23.599000  5.941200e+04     241.165877
# 25%    1967.000000            58.337500  2.678572e+06    2514.625266
# 50%    1982.000000            69.610000  7.557218e+06    7838.505123
# 75%    1996.000000            73.657750  1.958522e+07   17357.879170
# max    2007.000000            82.670000  1.318683e+09  113523.132900

# %%
df["Continente"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', nan, 'FSU', 'Oceania'],
#       dtype=object)

# %%
oceania = df.loc[df["Continente"] == "Oceania"]

# %%
oceania
# Out:
#                  Pais Continente  ...  Pop Total          PIB
# 975              Fiji    Oceania  ...     421869  2039.393277
# 976              Fiji    Oceania  ...     485000  2170.073285
# 977              Fiji    Oceania  ...     544000  2797.759484
# 978              Fiji    Oceania  ...     599339  3182.569600
# 979              Fiji    Oceania  ...     658906  3209.257468
# ...               ...        ...  ...        ...          ...
# 2696  Solomon Islands    Oceania  ...     300694  1783.648762
# 2697  Solomon Islands    Oceania  ...     358713  2109.894257
# 2698  Solomon Islands    Oceania  ...     424265  2252.491044
# 2699  Solomon Islands    Oceania  ...     494786  1530.496068
# 2700  Solomon Islands    Oceania  ...     566842  1829.317402
#
# [74 rows x 6 columns]

# %%
oceania.describe()
# Out:
#               Ano  Expectativa de Vida     Pop Total           PIB
# count    74.00000            74.000000  7.400000e+01     74.000000
# mean   1979.27027            70.396622  2.367617e+06  13078.961304
# std      15.99426             6.388423  1.214119e+06   7064.848672
# min    1950.00000            52.964000  1.510000e+05    864.974253
# 25%    1967.00000            68.870500  1.166084e+06   5679.365745
# 50%    1979.50000            71.340000  2.743575e+06  14940.586840
# 75%    1992.00000            74.300000  3.305738e+06  18554.854445
# max    2007.00000            80.204000  4.115771e+06  25185.009110

# %%
oceania["Continente"].unique()
# Out:
# array(['Oceania'], dtype=object)

# %%
df.groupby("Continente")["Pais"].unique()
# Out:
# Continente
# Africa      [Algeria, Angola, Benin, Botswana, Burkina Fas...
# Americas    [Argentina, Bolivia, Brazil, Chile, Colombia, ...
# Asia        [Afghanistan, Azerbaijan, Bahrain, Bangladesh,...
# Europe      [Albania, Austria, Belgium, Bosnia and Herzego...
# FSU         [Belarus, Kazakhstan, Latvia, Lithuania, Russi...
# Oceania                  [Fiji, New Zealand, Solomon Islands]
# Name: Pais, dtype: object

# %%
df.groupby("Ano")["Expectativa de Vida"].mean()
# Out:
# Ano
# 1950    62.002568
# 1951    65.904167
# 1952    49.206867
# 1953    66.674563
# 1954    67.459817
# 1955    67.806757
# 1956    67.950637
# 1957    51.614590
# 1958    68.815936
# 1959    68.226579
# 1960    68.470837
# 1961    68.862480
# 1962    54.035234
# 1963    69.595735
# 1964    70.063105
# 1965    70.259881
# 1966    70.447526
# 1967    56.263629
# 1968    70.689081
# 1969    70.653896
# 1970    70.961141
# 1971    71.103976
# 1972    58.474481
# 1973    71.500338
# 1974    71.778504
# 1975    71.939218
# 1976    72.158050
# 1977    60.429090
# 1978    72.717567
# 1979    73.018717
# 1980    73.064524
# 1981    73.337399
# 1982    62.365871
# 1983    73.787778
# 1984    74.100741
# 1985    74.112222
# 1986    74.452222
# 1987    63.984860
# 1988    74.760000
# 1989    74.924444
# 1990    74.283437
# 1991    74.374848
# 1992    65.008443
# 1993    74.324545
# 1994    74.456667
# 1995    74.552727
# 1996    75.029394
# 1997    65.873799
# 1998    75.569697
# ...

# %%
df["PIB"].mean()
# Out:
# 11317.115804696637

# %%
df["PIB"].sum()
# Out:
# 37482287.5451553

# %% [markdown]
# ## Visualização dos Dados

# %%
plt.hist(x = df["Ano"]);

# %%
plt.hist(x = df["Expectativa de Vida"]);

# %%
plt.hist(x = df["Pop Total"]);

# %%
plt.hist(x = df["PIB"]);

# %%
grafico = px.scatter_matrix(df, dimensions=["Ano", "Expectativa de Vida", "Pop Total", "Continente", "PIB"])
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8c797d42-0043-4560-9f8d-ddf0f669fa6a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8c797d42-0043-4560-9f8d-ddf0f669fa6a")) {
#                     Plotly.newPlot(
#                         '8c797d42-0043-4560-9f8d-ddf0f669fa6a',
# ...

# %% [markdown]
# ### PIB per capita x Expectativa de Vida

# %%
fig  = px.scatter(df, x = 'PIB', y = 'Expectativa de Vida', log_x = True, width = 800)
fig.update_traces(marker = dict(size = 12, line=dict(width = 2)), selector = dict(mode = 'markers'))
fig.update_layout(title = 'Logaritmo do PIB per Capita X Expectativa de vida')
fig.update_xaxes(title = 'Log(PIB per capita)')
fig.update_yaxes(title = 'Expectativa de vida')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5909854f-7671-469d-900b-d5f62d837251" class="plotly-graph-div" style="height:525px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5909854f-7671-469d-900b-d5f62d837251")) {
#                     Plotly.newPlot(
#                         '5909854f-7671-469d-900b-d5f62d837251',
# ...

# %%
fig = px.scatter(df, x = "PIB", y = "Expectativa de Vida", size = "Pop Total", color = "Pop Total",   
hover_name = "Pais", log_x = True, size_max = 60, width = 800) 
fig.update_layout(title = 'Logaritmo do PIB per capita X Expectativa de vida no ano de 2019') 
fig.update_xaxes(title = 'Log (PIB per capita)'), fig.update_yaxes(title = 'Expectativa de vida')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3d6f95ca-c72a-45f8-8619-dffd2f4ec56b" class="plotly-graph-div" style="height:525px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3d6f95ca-c72a-45f8-8619-dffd2f4ec56b")) {
#                     Plotly.newPlot(
#                         '3d6f95ca-c72a-45f8-8619-dffd2f4ec56b',
# ...

# %%
df_2007 = df[df["Ano"] == 2007]
px.scatter_3d(df_2007, x = "PIB", y = "Expectativa de Vida", z = "Pop Total")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4620e831-afb0-4a3b-96ee-987a8a099500" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4620e831-afb0-4a3b-96ee-987a8a099500")) {
#                     Plotly.newPlot(
#                         '4620e831-afb0-4a3b-96ee-987a8a099500',
# ...
